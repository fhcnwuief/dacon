# %%
import numpy as np
import pandas as pd

# preprocessing
import os
from datetime import datetime

# EDA
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import scipy.stats
from scipy.stats import skew
from scipy.stats import spearmanr

# Learning algorithms
import sklearn
from sklearn.linear_model import *
from sklearn.svm import SVR
from sklearn.cluster import KMeans

import lightgbm as lgb
from lightgbm import LGBMRegressor
# import catboost

# model validation
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings('ignore')

SEED = 2
np.random.seed(SEED)

# %%
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 

#f_path = "c:/Windows/Fonts/AppleGothic.ttf"(맥)
f_path = "c:/Windows/Fonts/malgun.ttf"

font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font',family = font_name)

# %%
main_path = 'C:/Users/Playdata/Documents/DataScience/source/99_Competition/source'
data_dir = 'data'
dir_path = f'{main_path}/{data_dir}'

test_name = 'test.csv'
train_name = 'train.csv'
building_name = 'building_info.csv'
sample_submission_name = 'sample_submission.csv'

# %%
def rename_dict(df):
    # 이름 정리
    targets = df.columns[df.columns.str.contains('\(')]
    if len(targets) == 7:
        # train_df
        df.rename(columns = {
            '기온(C)':'기온',
            '강수량(mm)':'강수량',
            '풍속(m/s)':'풍속',
            '습도(%)':'습도',
            '일조(hr)':'일조',
            '일사(MJ/m2)':'일사',
            '전력소비량(kWh)':'전력소비량'
        },inplace = True)
    elif len(targets) == 4:
        # test_df
        df.rename(columns = {
            '기온(C)':'기온',
            '강수량(mm)':'강수량',
            '풍속(m/s)':'풍속',
            '습도(%)':'습도',
        },inplace = True)
    else:
        # building_df
        df.rename(columns = {
            '연면적(m2)':'연면적',
            '냉방면적(m2)':'냉방면적', 
            '태양광용량(kW)':'태양광용량',
            'ESS저장용량(kWh)':'ESS저장용량',
            'PCS용량(kW)':'PCS용량'
        },inplace = True)
        
    return df

def data_datetime_setting(df):
    date_format = "%Y%m%d %H"
    # 일시 컬럼 이용하여 요일 확인
    df['요일'] = df['일시'].apply(lambda x: datetime.strptime(x, date_format).strftime("%a"))
    # 일시 컬럼 이용하여 연/월/일/시간 컬럼추가
    df['일시'] = pd.to_datetime(df['일시'], format='%Y%m%d %H')
    df['연'] = df['일시'].dt.year
    df['월'] = df['일시'].dt.month
    df['일'] = df['일시'].dt.day
    df['시간'] = df['일시'].dt.hour
    return df

def data_preprocessing(df):
    try:
        df['강수량'].fillna(0, inplace=True)
        df['풍속'].fillna(method='ffill', inplace=True)
        df['습도'].fillna(method='ffill', inplace=True)
        df['일조'].fillna(0, inplace=True)
        df['일사'].fillna(0, inplace=True)
    except:
        df['강수량'].fillna(0, inplace=True)
        df['일조'] = 0
        df['일사'] = 0
    return df

def merge_dfs(df):
    merge_df = df.merge(building_df)
    for col in merge_df.columns:
        merge_df[col] = merge_df[col].replace('-',0)
        merge_df[col] = merge_df[col].fillna(0)

    merge_df['태양광용량'] = merge_df['태양광용량'].astype('float64')
    merge_df['ESS저장용량'] = merge_df['ESS저장용량'].astype('float64')
    merge_df['PCS용량'] = merge_df['PCS용량'].astype('float64')
    merge_df.drop(['num_date_time'],axis=1,inplace=True) # 둘 다 없어도 알 수 있는 데이터라서
    return merge_df

# 요일, 건물유형은 원핫인코딩하기 > pd.get_dummies()

# %%
os.listdir(dir_path)
# Out:
# ['2019',
#  '2021',
#  'building_info.csv',
#  'sample_submission.csv',
#  'test.csv',
#  'train.csv']

# %%
# 제출 형식
pd.read_csv(f'{dir_path}/{sample_submission_name}').columns
# Out:
# Index(['num_date_time', 'answer'], dtype='object')

# %%
test_df = pd.read_csv(f'{dir_path}/{test_name}')
train_df = pd.read_csv(f'{dir_path}/{train_name}')
building_df = pd.read_csv(f'{dir_path}/{building_name}')

# %%
train_df = rename_dict(df = train_df)
# train_df = data_datetime_setting(df=train_df)
train_df = data_preprocessing(df=train_df)

building_df = rename_dict(df = building_df)

test_df = rename_dict(df = test_df)
test_df = data_preprocessing(df=test_df)

# %%
train_merge = merge_dfs(df = train_df)
test_merge = merge_dfs(df = test_df)

# %%
from tqdm import tqdm
import pandas as pd
import statsmodels.api as sm
predicts = []
# 데이터 불러오기 (예시)
for n in tqdm(range(1,len(train_merge['건물번호'].unique())+1)):
    train__ = train_merge[train_merge['건물번호'] == n]
    test__ = test_merge[test_merge['건물번호'] == n]
    n_data = train__.copy()
    t_data = test__.copy()
    n_data.set_index('일시', inplace=True)
    t_data.set_index('일시', inplace=True)

    # 다중 회귀를 위한 피쳐 선택
    features = ['건물번호', '기온', '강수량', '풍속', '습도', '일조', '일사', '연면적',
       '냉방면적', '태양광용량', 'ESS저장용량', 'PCS용량']
    # 종속 변수 설정
    target = '전력소비량'

#     # 훈련 데이터 분할 (예시)
#     index = int(len(data)*4/5)
#     train_data = data.iloc[:index]
#     test_data = data.iloc[index:]

    # 피쳐와 종속 변수 설정
    X_train = n_data[features]
    y_train = n_data[target]
    X_test = t_data[features]


    # 상수(intercept)를 추가하여 회귀 모델 피팅
    X_train = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train).fit()
    # 테스트 데이터 예측
    X_test = sm.add_constant(X_test)
    predictions = model.predict(X_test)
    
    test_merge.loc[test_merge[test_merge['건물번호']==n].index,'answer'] = predicts[n-1].values
    
    # 모델 결과 출력
    print(model.summary())
# Out:
#   6%|████▉                                                                             | 6/100 [00:00<00:03, 26.05it/s]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.621
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     554.1
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):               0.00
# Time:                        18:25:25   Log-Likelihood:                -16216.
# No. Observations:                2040   AIC:                         3.245e+04
# Df Residuals:                    2033   BIC:                         3.249e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -9.657e+05   1.25e+06     -0.770      0.441   -3.43e+06    1.49e+06
# 기온           113.2353      4.929     22.975      0.000     103.570     122.901
# 강수량           25.1160      5.806      4.326      0.000      13.731      36.501
# 풍속           145.9312     13.952     10.459      0.000     118.569     173.294
# 습도            17.3844      1.466     11.858      0.000      14.509      20.260
# 일조         -1108.3122     82.512    -13.432      0.000   -1270.129    -946.496
# 일사          1048.6607     31.422     33.373      0.000     987.038    1110.284
# 연면적         2.521e+10   3.27e+10      0.770      0.441    -3.9e+10    8.94e+10
# 냉방면적        -7.05e+10   9.16e+10     -0.770      0.441    -2.5e+11    1.09e+11
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       37.143   Durbin-Watson:                   0.372
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.007
# Skew:                           0.302   Prob(JB):                     2.05e-09
# Kurtosis:                       3.325   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     206.2
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          1.01e-205
# Time:                        18:25:25   Log-Likelihood:                -15501.
# No. Observations:                2040   AIC:                         3.102e+04
# Df Residuals:                    2033   BIC:                         3.106e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        1.355e+06   1.47e+06      0.922      0.357   -1.53e+06    4.24e+06
# 기온            69.7712      3.481     20.041      0.000      62.944      76.599
# 강수량           22.6738      4.337      5.228      0.000      14.168      31.180
# 풍속            37.2290      9.608      3.875      0.000      18.387      56.071
# 습도             6.8051      1.029      6.612      0.000       4.787       8.823
# 일조          -388.4981     58.107     -6.686      0.000    -502.453    -274.544
# 일사           349.5251     22.146     15.783      0.000     306.094     392.957
# 연면적        -3.151e+10   3.42e+10     -0.922      0.357   -9.85e+10    3.55e+10
# 냉방면적         3.89e+10   4.22e+10      0.922      0.357   -4.38e+10    1.22e+11
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       41.699   Durbin-Watson:                   0.305
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.339
# Skew:                           0.209   Prob(JB):                     1.57e-07
# Kurtosis:                       2.559   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.239
# Method:                 Least Squares   F-statistic:                     107.6
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          5.96e-118
# Time:                        18:25:25   Log-Likelihood:                -15751.
# No. Observations:                2040   AIC:                         3.152e+04
# Df Residuals:                    2033   BIC:                         3.156e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        2.114e-09   1.02e-08      0.208      0.836   -1.79e-08    2.21e-08
# 기온            74.1022      3.919     18.908      0.000      66.416      81.788
# 강수량           14.2537      4.621      3.085      0.002       5.192      23.315
# 풍속            52.7441     11.101      4.751      0.000      30.974      74.515
# 습도            -7.7172      1.162     -6.640      0.000      -9.996      -5.438
# 일조            90.3080     65.675      1.375      0.169     -38.490     219.106
# 일사           -78.5681     25.010     -3.141      0.002    -127.616     -29.520
# 연면적            0.0001      0.001      0.208      0.836      -0.001       0.001
# 냉방면적        8.028e-05      0.000      0.208      0.836      -0.001       0.001
# 태양광용량       2.818e-08   1.36e-07      0.208      0.836   -2.38e-07    2.94e-07
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      337.045   Durbin-Watson:                   0.190
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              540.401
# Skew:                           1.113   Prob(JB):                    4.50e-118
# Kurtosis:                       4.185   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     497.3
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):               0.00
# Time:                        18:25:25   Log-Likelihood:                -13428.
# No. Observations:                2040   AIC:                         2.687e+04
# Df Residuals:                    2032   BIC:                         2.692e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -1.344e+06   1.15e+06     -1.168      0.243    -3.6e+06    9.13e+05
# 기온            19.2858      1.257     15.344      0.000      16.821      21.751
# 강수량            6.5232      1.481      4.406      0.000       3.620       9.427
# 풍속            24.3557      3.558      6.845      0.000      17.378      31.334
# 습도             4.1106      0.374     10.995      0.000       3.377       4.844
# 일조          -320.0866     21.042    -15.212      0.000    -361.353    -278.820
# 일사           316.8934      8.013     39.546      0.000     301.178     332.609
# 연면적         7.694e+09   6.59e+09      1.168      0.243   -5.22e+09    2.06e+10
# 냉방면적       -1.661e+10   1.42e+10     -1.168      0.243   -4.45e+10    1.13e+10
# 태양광용량        6.99e+06   5.98e+06      1.168      0.243   -4.75e+06    1.87e+07
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       91.763   Durbin-Watson:                   0.358
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.239
# Skew:                           0.541   Prob(JB):                     3.82e-23
# Kurtosis:                       3.209   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.239
# Method:                 Least Squares   F-statistic:                     107.6
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          5.19e-118
# Time:                        18:25:25   Log-Likelihood:                -17804.
# No. Observations:                2040   AIC:                         3.562e+04
# Df Residuals:                    2033   BIC:                         3.566e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -1.586e+05   7.43e+05     -0.213      0.831   -1.62e+06     1.3e+06
# 기온           134.9531     10.732     12.575      0.000     113.907     156.000
# 강수량           15.6681     12.641      1.239      0.215      -9.123      40.459
# 풍속           -93.4889     30.380     -3.077      0.002    -153.068     -33.910
# 습도            14.2361      3.192      4.460      0.000       7.976      20.496
# 일조          -774.9421    179.662     -4.313      0.000   -1127.283    -422.601
# 일사           884.5065     68.419     12.928      0.000     750.328    1018.685
# 연면적         6.442e+09   3.02e+10      0.213      0.831   -5.27e+10    6.56e+10
# 냉방면적       -8.844e+09   4.14e+10     -0.213      0.831   -9.01e+10    7.24e+10
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량     1.221e+08   5.72e+08      0.213      0.831   -9.99e+08    1.24e+09
# PCS용량       1.529e+07   7.16e+07      0.213      0.831   -1.25e+08    1.56e+08
# ==============================================================================
# Omnibus:                      348.861   Durbin-Watson:                   0.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              560.543
# Skew:                           1.153   Prob(JB):                    1.90e-122
# Kurtosis:                       4.129   Cond. No.                     1.44e+49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.34e-85. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.645
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     616.5
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):               0.00
# Time:                        18:25:25   Log-Likelihood:                -15401.
# No. Observations:                2040   AIC:                         3.082e+04
# Df Residuals:                    2033   BIC:                         3.086e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        5.654e+04   5.81e+05      0.097      0.922   -1.08e+06     1.2e+06
# 기온            70.2191      3.343     21.004      0.000      63.663      76.775
# 강수량            9.3974      3.043      3.088      0.002       3.429      15.366
# 풍속           108.5883      9.783     11.099      0.000      89.402     127.775
# 습도             1.8953      0.825      2.297      0.022       0.277       3.513
# 일조          -564.8724     49.618    -11.384      0.000    -662.180    -467.565
# 일사           627.0235     22.365     28.036      0.000     583.163     670.884
# 연면적        -1.115e+09   1.15e+10     -0.097      0.922   -2.36e+10    2.13e+10
# 냉방면적        3.077e+09   3.16e+10      0.097      0.922   -5.89e+10    6.51e+10
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       20.814   Durbin-Watson:                   0.281
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.653
# Skew:                           0.205   Prob(JB):                     5.40e-05
# Kurtosis:                       2.748   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     246.8
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          2.49e-237
# Time:                        18:25:26   Log-Likelihood:                -13913.
# No. Observations:                2040   AIC:                         2.784e+04
# Df Residuals:                    2033   BIC:                         2.788e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        5.411e-07   3.06e-08     17.690      0.000    4.81e-07    6.01e-07
# 기온            -6.0140      1.611     -3.733      0.000      -9.173      -2.855
# 강수량            7.0727      1.468      4.819      0.000       4.194       9.951
# 풍속            49.8819      4.716     10.576      0.000      40.633      59.131
# 습도            -2.7025      0.397     -6.809      0.000      -3.481      -1.924
# 일조          -103.8345     23.929     -4.339      0.000    -150.763     -56.906
# 일사           184.0803     10.785     17.067      0.000     162.928     205.232
# 연면적            0.0079      0.000     17.690      0.000       0.007       0.009
# 냉방면적           0.0032      0.000     17.690      0.000       0.003       0.004
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량     6.184e-05    3.5e-06     17.690      0.000     5.5e-05    6.87e-05
# PCS용량       2.319e-05   1.31e-06     17.690      0.000    2.06e-05    2.58e-05
# ==============================================================================
# Omnibus:                       33.015   Durbin-Watson:                   0.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.163
# Skew:                           0.224   Prob(JB):                     7.67e-07
# Kurtosis:                       2.638   Cond. No.                     5.15e+48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.26e-85. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#   9%|███████▍                                                                          | 9/100 [00:00<00:04, 21.55it/s]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     110.1
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          3.93e-103
# Time:                        18:25:26   Log-Likelihood:                -13204.
# No. Observations:                2040   AIC:                         2.642e+04
# Df Residuals:                    2034   BIC:                         2.645e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        7.565e-07   5.11e-08     14.798      0.000    6.56e-07    8.57e-07
# 기온            17.7440      1.029     17.240      0.000      15.726      19.762
# 강수량            2.1596      1.505      1.435      0.152      -0.793       5.112
# 풍속            38.6627      4.586      8.430      0.000      29.668      47.657
# 습도             2.8915      0.317      9.127      0.000       2.270       3.513
# 일조            57.2840     14.948      3.832      0.000      27.969      86.599
# 일사                  0          0        nan        nan           0           0
# 연면적            0.0071      0.000     14.798      0.000       0.006       0.008
# 냉방면적           0.0023      0.000     14.798      0.000       0.002       0.003
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       11.117   Durbin-Watson:                   0.500
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               10.671
# Skew:                          -0.148   Prob(JB):                      0.00482
# Kurtosis:                       2.804   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     492.1
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):               0.00
# Time:                        18:25:26   Log-Likelihood:                -15790.
# No. Observations:                2040   AIC:                         3.159e+04
# Df Residuals:                    2033   BIC:                         3.163e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -8.557e-08   2.54e-08     -3.367      0.001   -1.35e-07   -3.57e-08
# 기온           109.6700      3.657     29.985      0.000     102.497     116.843
# 강수량           92.6816     13.602      6.814      0.000      66.007     119.356
# 풍속            77.3183      9.866      7.837      0.000      57.970      96.667
# 습도            -5.3341      1.261     -4.232      0.000      -7.806      -2.862
# 일조          -830.7592     74.914    -11.090      0.000    -977.675    -683.844
# 일사           458.8461     29.710     15.444      0.000     400.581     517.112
# 연면적           -0.0021      0.001     -3.367      0.001      -0.003      -0.001
# 냉방면적          -0.0001   4.42e-05     -3.367      0.001      -0.000   -6.21e-05
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       26.324   Durbin-Watson:                   0.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.968
# Skew:                           0.067   Prob(JB):                     0.000207
# Kurtosis:                       2.574   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     142.5
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          5.32e-151
# Time:                        18:25:26   Log-Likelihood:                -15511.
# No. Observations:                2040   AIC:                         3.104e+04
# Df Residuals:                    2033   BIC:                         3.108e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호         6.77e-06   1.03e-06      6.573      0.000    4.75e-06    8.79e-06
# 기온            96.0268      3.497     27.457      0.000      89.168     102.885
# 강수량           -4.9835      8.174     -0.610      0.542     -21.014      11.047
# 풍속           -36.6351      5.398     -6.787      0.000     -47.220     -26.050
# 습도            11.2561      1.258      8.946      0.000       8.789      13.724
# 일조           -82.0338     54.630     -1.502      0.133    -189.170      25.102
# 일사            -6.1701     20.732     -0.298      0.766     -46.829      34.489
# 연면적            0.0210      0.003      6.573      0.000       0.015       0.027
# 냉방면적           0.0126      0.002      6.573      0.000       0.009       0.016
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       26.133   Durbin-Watson:                   0.231
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.844
# Skew:                          -0.147   Prob(JB):                     4.91e-05
# Kurtosis:                       2.617   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.466
# Method:                 Least Squares   F-statistic:                     357.0
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          4.36e-275
# Time:                        18:25:26   Log-Likelihood:                -13979.
# No. Observations:                2040   AIC:                         2.797e+04
# Df Residuals:                    2034   BIC:                         2.800e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        1.885e+07    5.4e+07      0.349      0.727    -8.7e+07    1.25e+08
# 기온            44.2223      1.507     29.337      0.000      41.266      47.178
# 강수량           -0.2540      2.201     -0.115      0.908      -4.570       4.063
# 풍속            46.6729      6.709      6.957      0.000      33.516      59.830
# 습도             1.9290      0.464      4.154      0.000       1.018       2.840
# 일조           197.2828     21.864      9.023      0.000     154.405     240.161
# 일사            -0.7027      2.013     -0.349      0.727      -4.650       3.244
# 연면적        -8.458e+09   2.42e+10     -0.349      0.727    -5.6e+10     3.9e+10
# 냉방면적        2.944e+10   8.43e+10      0.349      0.727   -1.36e+11    1.95e+11
# 태양광용량       8.948e+08   2.56e+09      0.349      0.727   -4.13e+09    5.92e+09
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       53.467   Durbin-Watson:                   0.370
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.328
# Skew:                           0.410   Prob(JB):                     3.56e-13
# Kurtosis:                       2.979   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.500
# Method:                 Least Squares   F-statistic:                     341.0
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          4.94e-303
# Time:                        18:25:26   Log-Likelihood:                -13658.
# No. Observations:                2040   AIC:                         2.733e+04
# Df Residuals:                    2033   BIC:                         2.737e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -1.162e-07   1.13e-07     -1.029      0.304   -3.38e-07    1.05e-07
# 기온            41.7620      1.421     29.390      0.000      38.975      44.549
# 강수량            1.8408      1.295      1.422      0.155      -0.698       4.380
# 풍속            45.5436      4.160     10.948      0.000      37.385      53.702
# 습도             3.6181      0.350     10.334      0.000       2.932       4.305
# 일조           -68.4788     21.107     -3.244      0.001    -109.873     -27.084
# 일사            97.2921      9.514     10.227      0.000      78.635     115.950
# 연면적           -0.0007      0.001     -1.029      0.304      -0.002       0.001
# 냉방면적       -3.485e-05   3.39e-05     -1.029      0.304      -0.000    3.16e-05
# 태양광용량      -1.265e-06   1.23e-06     -1.029      0.304   -3.68e-06    1.15e-06
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       24.886   Durbin-Watson:                   0.196
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.527
# Skew:                          -0.267   Prob(JB):                     2.86e-06
# Kurtosis:                       2.877   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#  17%|█████████████▊                                                                   | 17/100 [00:00<00:03, 26.14it/s]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     121.0
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          7.96e-149
# Time:                        18:25:26   Log-Likelihood:                -14429.
# No. Observations:                2040   AIC:                         2.887e+04
# Df Residuals:                    2032   BIC:                         2.892e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호         8.33e+07   2.97e+08      0.281      0.779   -4.99e+08    6.66e+08
# 기온            51.7160      2.059     25.112      0.000      47.677      55.755
# 강수량          -22.8201      4.810     -4.744      0.000     -32.254     -13.387
# 풍속            20.3676      3.177      6.412      0.000      14.138      26.597
# 습도             2.2858      0.742      3.080      0.002       0.831       3.741
# 일조            67.8884     32.149      2.112      0.035       4.839     130.938
# 일사          -139.1073     12.202    -11.400      0.000    -163.037    -115.178
# 연면적        -3.228e+10   1.15e+11     -0.281      0.779   -2.58e+11    1.93e+11
# 냉방면적        5.145e+10   1.83e+11      0.281      0.779   -3.08e+11    4.11e+11
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       41.775   Durbin-Watson:                   0.314
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.997
# Skew:                          -0.356   Prob(JB):                     2.79e-10
# Kurtosis:                       2.901   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     5.717
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):           6.58e-06
# Time:                        18:25:26   Log-Likelihood:                -15303.
# No. Observations:                2040   AIC:                         3.062e+04
# Df Residuals:                    2033   BIC:                         3.066e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        1.501e+08   2.15e+08      0.699      0.485   -2.71e+08    5.71e+08
# 기온             5.8181      3.358      1.733      0.083      -0.767      12.404
# 강수량            1.6785      2.873      0.584      0.559      -3.957       7.314
# 풍속            24.0641      7.175      3.354      0.001       9.993      38.135
# 습도             0.4398      0.887      0.496      0.620      -1.300       2.179
# 일조          -150.1734     49.260     -3.049      0.002    -246.779     -53.567
# 일사            62.0200     18.646      3.326      0.001      25.452      98.588
# 연면적        -9.626e+10   1.38e+11     -0.699      0.485   -3.66e+11    1.74e+11
# 냉방면적         1.15e+11   1.64e+11      0.699      0.485   -2.08e+11    4.37e+11
# 태양광용량       8.183e+08   1.17e+09      0.699      0.485   -1.48e+09    3.11e+09
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       79.097   Durbin-Watson:                   0.571
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.884
# Skew:                          -0.129   Prob(JB):                     3.60e-09
# Kurtosis:                       2.375   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     91.30
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          1.12e-101
# Time:                        18:25:26   Log-Likelihood:                -13848.
# No. Observations:                2040   AIC:                         2.771e+04
# Df Residuals:                    2033   BIC:                         2.775e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        2.634e-07   1.73e-08     15.224      0.000     2.3e-07    2.97e-07
# 기온            27.9901      1.357     20.634      0.000      25.330      30.650
# 강수량           -4.8420      5.279     -0.917      0.359     -15.194       5.510
# 풍속             5.1870      4.360      1.190      0.234      -3.363      13.737
# 습도             1.3734      0.457      3.003      0.003       0.476       2.270
# 일조          -110.8722     23.255     -4.768      0.000    -156.478     -65.266
# 일사           -42.8333      9.542     -4.489      0.000     -61.546     -24.121
# 연면적            0.0029      0.000     15.224      0.000       0.003       0.003
# 냉방면적           0.0029      0.000     15.224      0.000       0.003       0.003
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       48.073   Durbin-Watson:                   0.230
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.681
# Skew:                          -0.355   Prob(JB):                     2.69e-11
# Kurtosis:                       2.739   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     216.9
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          3.00e-214
# Time:                        18:25:26   Log-Likelihood:                -17238.
# No. Observations:                2040   AIC:                         3.449e+04
# Df Residuals:                    2033   BIC:                         3.453e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -3.289e-07    6.9e-08     -4.764      0.000   -4.64e-07   -1.94e-07
# 기온           125.4597      7.832     16.018      0.000     110.100     140.820
# 강수량          116.2467     23.571      4.932      0.000      70.021     162.473
# 풍속           119.5399     27.036      4.422      0.000      66.520     172.560
# 습도            12.0494      2.719      4.432      0.000       6.718      17.381
# 일조            24.1157    123.258      0.196      0.845    -217.608     265.840
# 일사           544.1122     50.778     10.716      0.000     444.530     643.694
# 연면적           -0.0049      0.001     -4.764      0.000      -0.007      -0.003
# 냉방면적          -0.0020      0.000     -4.764      0.000      -0.003      -0.001
# 태양광용량      -4.111e-07   8.63e-08     -4.764      0.000    -5.8e-07   -2.42e-07
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      908.409   Durbin-Watson:                   0.310
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              121.961
# Skew:                          -0.216   Prob(JB):                     3.28e-27
# Kurtosis:                       1.882   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     100.3
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          1.01e-110
# Time:                        18:25:26   Log-Likelihood:                -15043.
# No. Observations:                2040   AIC:                         3.010e+04
# Df Residuals:                    2033   BIC:                         3.014e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -3.113e-07   2.61e-07     -1.194      0.233   -8.23e-07       2e-07
# 기온            10.0903      2.770      3.643      0.000       4.658      15.523
# 강수량           11.2452      3.266      3.443      0.001       4.840      17.650
# 풍속            54.8241      7.846      6.987      0.000      39.437      70.211
# 습도             7.2562      0.821      8.834      0.000       5.645       8.867
# 일조          -141.7868     46.419     -3.055      0.002    -232.820     -50.753
# 일사           276.2464     17.677     15.628      0.000     241.580     310.913
# 연면적           -0.0012      0.001     -1.194      0.233      -0.003       0.001
# 냉방면적          -0.0009      0.001     -1.194      0.233      -0.002       0.001
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      213.419   Durbin-Watson:                   0.163
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.014
# Skew:                           0.128   Prob(JB):                     4.63e-15
# Kurtosis:                       2.157   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.425
# Method:                 Least Squares   F-statistic:                     216.1
# ...
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        8.656e+06   1.89e+07      0.459      0.646   -2.83e+07    4.56e+07
# 기온            30.7499      1.758     17.496      0.000      27.303      34.197
# 강수량            9.3795      6.911      1.357      0.175      -4.174      22.933
# 풍속            22.8227      7.169      3.183      0.001       8.763      36.883
# 습도             0.8266      0.589      1.404      0.160      -0.328       1.981
# 일조           167.6282     21.940      7.640      0.000     124.600     210.656
# 일사             0.2820      0.614      0.459      0.646      -0.922       1.486
# 연면적         -2.95e+09   6.43e+09     -0.459      0.646   -1.56e+10    9.65e+09
# 냉방면적        1.019e+10   2.22e+10      0.459      0.646   -3.33e+10    5.37e+10
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       65.823   Durbin-Watson:                   0.714
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.965
# Skew:                           0.380   Prob(JB):                     4.32e-18
# Kurtosis:                       3.603   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 26.25it/s]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     535.7
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):               0.00
# Time:                        18:25:29   Log-Likelihood:                -15276.
# No. Observations:                2040   AIC:                         3.057e+04
# Df Residuals:                    2033   BIC:                         3.061e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호         1.78e+07   2.78e+07      0.641      0.521   -3.67e+07    7.23e+07
# 기온           111.9844      3.118     35.912      0.000     105.869     118.100
# 강수량           43.7732      7.091      6.173      0.000      29.867      57.679
# 풍속             0.0454      4.584      0.010      0.992      -8.945       9.036
# 습도             2.8914      1.130      2.559      0.011       0.676       5.107
# 일조          -284.9883     48.855     -5.833      0.000    -380.800    -189.177
# 일사           327.3023     18.648     17.552      0.000     290.731     363.873
# 연면적        -1.907e+10   2.97e+10     -0.641      0.521   -7.74e+10    3.93e+10
# 냉방면적        2.941e+10   4.59e+10      0.641      0.521   -6.06e+10    1.19e+11
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      301.917   Durbin-Watson:                   0.236
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.969
# Skew:                           0.171   Prob(JB):                     2.62e-18
# Kurtosis:                       2.086   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     534.8
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):               0.00
# Time:                        18:25:29   Log-Likelihood:                -13789.
# No. Observations:                2040   AIC:                         2.759e+04
# Df Residuals:                    2033   BIC:                         2.763e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        8.265e+06   1.07e+07      0.776      0.438   -1.26e+07    2.92e+07
# 기온            50.4213      1.507     33.468      0.000      47.467      53.376
# 강수량           17.5176      3.371      5.196      0.000      10.906      24.129
# 풍속            23.0881      3.146      7.338      0.000      16.918      29.258
# 습도             5.5036      0.626      8.794      0.000       4.276       6.731
# 일조           100.3299     20.837      4.815      0.000      59.466     141.194
# 일사            80.2526      8.326      9.639      0.000      63.924      96.581
# 연면적         1.237e+10    1.6e+10      0.776      0.438   -1.89e+10    4.37e+10
# 냉방면적       -2.636e+10    3.4e+10     -0.776      0.438    -9.3e+10    4.03e+10
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       33.967   Durbin-Watson:                   0.314
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.941
# Skew:                           0.200   Prob(JB):                     1.41e-06
# Kurtosis:                       2.603   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     297.0
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          4.82e-239
# Time:                        18:25:29   Log-Likelihood:                -14651.
# No. Observations:                2040   AIC:                         2.931e+04
# Df Residuals:                    2034   BIC:                         2.935e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -2.714e-06   2.87e-06     -0.947      0.344   -8.34e-06    2.91e-06
# 기온            46.0593      2.036     22.624      0.000      42.067      50.052
# 강수량           41.3182      6.468      6.388      0.000      28.633      54.003
# 풍속            24.4803      6.488      3.773      0.000      11.757      37.203
# 습도            -0.8407      0.773     -1.087      0.277      -2.357       0.676
# 일조           298.0359     24.029     12.403      0.000     250.911     345.161
# 일사                  0          0        nan        nan           0           0
# 연면적           -0.0015      0.002     -0.947      0.344      -0.005       0.002
# 냉방면적          -0.0005      0.001     -0.947      0.344      -0.001       0.001
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       75.107   Durbin-Watson:                   0.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.802
# Skew:                          -0.018   Prob(JB):                     4.57e-08
# Kurtosis:                       2.370   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     294.8
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):          1.23e-237
# Time:                        18:25:29   Log-Likelihood:                -14431.
# No. Observations:                2040   AIC:                         2.887e+04
# Df Residuals:                    2034   BIC:                         2.891e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호       -1.132e-05   1.74e-06     -6.517      0.000   -1.47e-05   -7.91e-06
# 기온            49.2030      1.757     28.003      0.000      45.757      52.649
# 강수량            8.6606      4.059      2.134      0.033       0.700      16.621
# 풍속            66.5934      6.000     11.098      0.000      54.826      78.361
# 습도             4.3009      0.607      7.082      0.000       3.110       5.492
# 일조           254.8159     20.399     12.491      0.000     214.810     294.822
# 일사                  0          0        nan        nan           0           0
# 연면적           -0.0061      0.001     -6.517      0.000      -0.008      -0.004
# 냉방면적          -0.0046      0.001     -6.517      0.000      -0.006      -0.003
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      323.942   Durbin-Watson:                   0.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.706
# Skew:                          -0.133   Prob(JB):                     4.92e-18
# Kurtosis:                       2.069   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  전력소비량   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     453.0
# Date:                Wed, 16 Aug 2023   Prob (F-statistic):               0.00
# Time:                        18:25:29   Log-Likelihood:                -13848.
# No. Observations:                2040   AIC:                         2.771e+04
# Df Residuals:                    2034   BIC:                         2.774e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 건물번호        1.668e+06   1.73e+08      0.010      0.992   -3.38e+08    3.41e+08
# 기온            38.6753      1.488     25.993      0.000      35.757      41.593
# 강수량           -0.4227      1.524     -0.277      0.781      -3.411       2.565
# 풍속            34.0031      5.053      6.730      0.000      24.094      43.912
# 습도            -1.8600      0.497     -3.740      0.000      -2.835      -0.885
# 일조           163.1420     19.041      8.568      0.000     125.800     200.484
# 일사             0.0092      0.958      0.010      0.992      -1.870       1.888
# 연면적        -3.039e+08   3.16e+10     -0.010      0.992   -6.22e+10    6.16e+10
# 냉방면적        4.365e+08   4.53e+10      0.010      0.992   -8.84e+10    8.93e+10
# 태양광용량               0          0        nan        nan           0           0
# ESS저장용량             0          0        nan        nan           0           0
# PCS용량               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       62.863   Durbin-Watson:                   0.225
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.126
# Skew:                          -0.149   Prob(JB):                     2.36e-08
# Kurtosis:                       2.431   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 건물별로

# %%
test_merge['num_date_time'] = test_merge['건물번호'].astype('str') + '_' + test_merge['일시'].astype('str')

# %%
# test_merge[['num_date_time','answer']].to_csv('../output/submission.csv',index=False)

# %%
test_merge[['num_date_time','answer']]
# Out:
#          num_date_time       answer
# 0        1_20220825 00  1816.315399
# 1        1_20220825 01  1569.815399
# 2        1_20220825 02  1675.815399
# 3        1_20220825 03  1630.815399
# 4        1_20220825 04  1535.315399
# ...                ...          ...
# 16795  100_20220831 19   662.838498
# 16796  100_20220831 20   555.760373
# 16797  100_20220831 21   530.842404
# 16798  100_20220831 22   552.637326
# 16799  100_20220831 23   476.238888
#
# [16800 rows x 2 columns]
